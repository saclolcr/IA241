# %% [markdown]
# # IA 241 FINAL: Analyzing the Global Pandemic of COVID-19 using Python

# %% [markdown]
# # DATA SOURCE

# %% [markdown]
# The following data is provided by European Centre for Disease Prevention and Control and is the COVID-19 situation update worldwide, as of 5 May 2020
# https://www.ecdc.europa.eu/en/geographical-distribution-2019-ncov-cases

# %% [markdown]
# # Background of COVID-19
# At the end of December 2019, Chinese public health authorities reported several cases of acute respiratory syndrome in Wuhan City, Hubei province, China. Chinese scientists soon identified a novel coronavirus as the main causative agent. The disease is now referred to as coronavirus disease 2019 (COVID-19), and the causative virus is called severe acute respiratory syndrome coronavirus 2 (SARS-CoV-2). It is a new strain of coronavirus that has not been previously identified in humans.
#
# The initial outbreak in Wuhan spread rapidly, affecting other parts of China. Cases were soon detected in several other countries. Outbreaks and clusters of the disease have since been observed in Asia, Europe, Australia, Africa and the Americas.
#
# https://www.ecdc.europa.eu/en/covid-19-pandemic

# %%
# %matplotlib inline

# %%
import pandas

# %% [markdown]
# #  IMPORT DATA FROM S3

# %%
df = pandas.read_excel("s3://saclolcr-ia241/COVID_19_5.xlsx")
df
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 0     2020-05-05    5      5  2020    190       5             Afghanistan
# 1     2020-05-04    4      5  2020    235      13             Afghanistan
# 2     2020-05-03    3      5  2020    134       4             Afghanistan
# 3     2020-05-02    2      5  2020    164       4             Afghanistan
# 4     2020-05-01    1      5  2020    222       4             Afghanistan
# 5     2020-04-30   30      4  2020    122       0             Afghanistan
# 6     2020-04-29   29      4  2020    124       3             Afghanistan
# 7     2020-04-28   28      4  2020    172       0             Afghanistan
# 8     2020-04-27   27      4  2020     68      10             Afghanistan
# 9     2020-04-26   26      4  2020    112       4             Afghanistan
# 10    2020-04-25   25      4  2020     70       1             Afghanistan
# 11    2020-04-24   24      4  2020    105       2             Afghanistan
# ...

# %% [markdown]
# # 1) What is the Total Death Number Per Day Globally?

# %%
avg_deaths_per_day = df.groupby("dateRep").sum()["deaths"]
avg_deaths_per_day
# Out:
# dateRep
# 2019-12-31        0
# 2020-01-01        0
# 2020-01-02        0
# 2020-01-03        0
# 2020-01-04        0
# 2020-01-05        0
# 2020-01-06        0
# 2020-01-07        0
# 2020-01-08        0
# 2020-01-09        0
# 2020-01-10        0
# 2020-01-11        1
# 2020-01-12        0
# 2020-01-13        0
# 2020-01-14        0
# 2020-01-15        1
# 2020-01-16        0
# 2020-01-17        0
# 2020-01-18        0
# 2020-01-19        1
# 2020-01-20        0
# 2020-01-21        3
# 2020-01-22       11
# 2020-01-23        0
# 2020-01-24        9
# 2020-01-25       15
# 2020-01-26       15
# 2020-01-27       25
# 2020-01-28       25
# 2020-01-29       26
#               ...
# 2020-04-06     4678
# 2020-04-07     5266
# 2020-04-08     7663
# 2020-04-09     6436
# 2020-04-10     7445
# 2020-04-11     7221
# 2020-04-12     6026
# 2020-04-13     5266
# 2020-04-14     5371
# 2020-04-15     7604
# 2020-04-16    10520
# 2020-04-17     8709
# 2020-04-18     8568
# 2020-04-19     6493
# ...

# %%
avg_deaths_per_day.plot()

# %% [markdown]
# # 2)What are the Top 10 Countries with the Highest Case Number?

# %%
sum_cases_per_country = df.groupby("countriesAndTerritories").sum()["cases"]
sum_cases_per_country
# Out:
# countriesAndTerritories
# Afghanistan                             2894
# Albania                                  803
# Algeria                                 4648
# Andorra                                  750
# Angola                                    35
# Anguilla                                   3
# Antigua_and_Barbuda                       25
# Argentina                               4874
# Armenia                                 2507
# Aruba                                    100
# Australia                               6825
# Austria                                15621
# Azerbaijan                              1984
# Bahamas                                   83
# Bahrain                                 3533
# Bangladesh                             10143
# Barbados                                  82
# Belarus                                17489
# Belgium                                50267
# Belize                                    18
# ...

# %%
sum_cases_per_country.nlargest(10).plot.bar()

# %% [markdown]
# # 3) Are the amount of cases related to amount of deaths in Italy?

# %%
italy_data = df.loc[df["countriesAndTerritories"] == "Italy"]
italy_data[:10]
# Out:
#         dateRep  day  month  year  cases  deaths countriesAndTerritories  \
# 7231 2020-05-05    5      5  2020   1221     195                   Italy
# 7232 2020-05-04    4      5  2020   1389     174                   Italy
# 7233 2020-05-03    3      5  2020   1900     474                   Italy
# 7234 2020-05-02    2      5  2020   1965     269                   Italy
# 7235 2020-05-01    1      5  2020   1872     285                   Italy
# 7236 2020-04-30   30      4  2020   2086     323                   Italy
# 7237 2020-04-29   29      4  2020   2091     382                   Italy
# 7238 2020-04-28   28      4  2020   1739     333                   Italy
# 7239 2020-04-27   27      4  2020   2324     260                   Italy
# 7240 2020-04-26   26      4  2020   2357     415                   Italy
#
#      geoId countryterritoryCode  popData2018 continentExp
# 7231    IT                  ITA   60431283.0       Europe
# ...

# %%
italy_data.plot.scatter(x="cases", y="deaths")

# %% [markdown]
# # Explanation of your calculation/ Interpretation of your visualizations

# %% [markdown]
# # Q1

# %% [markdown]
# The total daily death count is calculated by grouping the values for "dateREP" and finding the sum of of "deaths".

# %% [markdown]
# The line chart depicts exponential growth of deaths beginning in March to April.

# %% [markdown]
# # Q2

# %% [markdown]
# The top 10 countires with the highest case number is answered with the following steps:

# %% [markdown]
# 1- group by "countriesandTerritories" and find the sum of "cases"

# %% [markdown]
# 2- nlargest(10) to display the top 10

# %% [markdown]
# USA has the highest case count globally; 6 out of the 10 countries with COVID-19 cases are European

# %% [markdown]
# # Q3

# %% [markdown]
# Coorelation between cases count and deaths in Italy is calculated by:

# %% [markdown]
# Selecting the Italy data and then creating a scatter plot with cases as the x variable and deaths as the y variable

# %% [markdown]
# The scatter plot depicts that as the number of cases in Italy increase, the number of deaths also increase.

# %% [markdown]
# # CONCLUSION

# %% [markdown]
# Q1 The daily death count was increasing at an exponential rate from March to April and began to decrease going into May. This decrease is likely due to social distancing and mandated quarantines put in effect by goverments around the world.

# %% [markdown]
# Q2 As of 5 May 2020, USA and Europe most likely have the greatest concentrations of COVID-19 cases

# %% [markdown]
# Q3 The scatter plot depicts a postitive linear relationship between cases and deaths

# %% [markdown]
# # LIMITATIONS

# %% [markdown]
# 1 Assesments and calculations are created from my fundamental statistics and python knowledge

# %% [markdown]
# 2 Data is outdated (05 May 2020) and 07 May 2020 data is available

# %% [markdown]
# 3 Data may not be accurately represent all COVID-19 cases due to the incubation period of the virus as well as the varying domestic health capabilities for each country.
